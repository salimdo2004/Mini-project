# %% [markdown]
# <a href="https://colab.research.google.com/github/salimdo2004/Mini-project/blob/main/Untitled60.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# %%
df=pd.read_csv('Mall_Customers.csv', sep=",")
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# None

# %%
df.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
print(df["Genre"].unique())
# Out:
# ['Male' 'Female']

# %% [markdown]
# # nettoyage

# %%
df=df.dropna()

# %% [markdown]
# Préparation des données

# %%
# Renommer les colonnes pour faciliter
df.rename(columns={
    "Annual Income (k$)": "Income",
    "Spending Score (1-100)": "Score"
}, inplace=True)

# %% [markdown]
# ***Encoder Genre ***

# %%
df["Genre"] = df["Genre"].map({"Male": 0, "Female": 1})

# %% [markdown]
# *** Features pour clustering***

# %%
X = df[["Age", "Income", "Score"]]

# %%
import seaborn as sns

# Distribution
df.hist(figsize=(10,6))
plt.show()

# %%
# Correlation
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
# Boxplot
sns.boxplot(data=df[["Age", "Income", "Score"]])
plt.show()

# %% [markdown]
# ***Scaling***

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
inertia = []

for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

plt.plot(range(1, 11), inertia, marker='o')
plt.title("Elbow Method")
plt.xlabel("Number of clusters")
plt.ylabel("Inertia")
plt.show()

# %% [markdown]
# ***Choix k=5***

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
df["Cluster"] = kmeans.fit_predict(X_scaled)

print(df.head())
# Out:
#    CustomerID  Genre  Age  Income  Score  Cluster
# 0           1      0   19      15     39        2
# 1           2      0   21      15     81        2
# 2           3      1   20      16      6        3
# 3           4      1   23      16     77        2
# 4           5      1   31      17     40        2

# %%
best_k = silhouette_scores.index(max(silhouette_scores)) + 2
print("Best K:", best_k)
# Out:
# Best K: 6

# %% [markdown]
# Silhouette Score

# %%
silhouette_scores = []

for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)
    score = silhouette_score(X_scaled, labels)
    silhouette_scores.append(score)

plt.plot(range(2, 11), silhouette_scores, marker='o')
plt.title("Silhouette Score Method")
plt.xlabel("Number of clusters")
plt.ylabel("Score")
plt.show()

# %% [markdown]
# Ajouter DBSCAN

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=0.8, min_samples=5)
df["DBSCAN_Cluster"] = dbscan.fit_predict(X_scaled)

# %% [markdown]
# Afficher les CENTROÏDES

# %%
centroids = kmeans.cluster_centers_
print("Centroids:\n", centroids)
# Out:
# Centroids:
#  [[ 1.2825375  -0.26992    -0.0474887 ]
#  [-0.42973399  0.68673384  1.241219  ]
#  [ 0.51313183  0.75291925 -1.2962704 ]
#  [-1.28103541  0.10180828 -0.36951067]
#  [-0.97439592 -1.32954532  1.13217788]
#  [-0.3415442  -1.41282407 -0.96065717]
#  [-0.39047603 -0.28335596  0.004588  ]
#  [-0.47724849  1.87564575  1.23452563]
#  [ 1.17338538 -1.28478299 -1.44416206]
#  [ 0.15429838  1.87564575 -1.09476801]]

# %%
centroids_df = pd.DataFrame(
    scaler.inverse_transform(centroids),
    columns=["Age", "Income", "Score"]
)

print(centroids_df)
# Out:
#          Age      Income      Score
# 0  56.720930   53.488372  48.976744
# 1  32.862069   78.551724  82.172414
# 2  46.000000   80.285714  16.809524
# 3  21.000000   63.227273  40.681818
# 4  25.272727   25.727273  79.363636
# 5  34.090909   23.545455  25.454545
# 6  33.409091   53.136364  50.318182
# 7  32.200000  109.700000  82.000000
# 8  55.200000   26.900000  13.000000
# 9  41.000000  109.700000  22.000000

# %%
from sklearn.ensemble import IsolationForest

iso = IsolationForest(contamination=0.05)
df["Anomaly"] = iso.fit_predict(X_scaled)

# %% [markdown]
# Interprétation des clusters

# %%
for i in range(5):
    print(f"\nCluster {i}")
    print(df[df["Cluster"] == i][["Age", "Income", "Score"]].mean())
# Out:
# Cluster 0
# Age       55.275862
# Income    47.620690
# Score     41.706897
# dtype: float64
#
# Cluster 1
# Age       32.875
# Income    86.100
# Score     81.525
# dtype: float64
#
# Cluster 2
# Age       25.769231
# Income    26.115385
# Score     74.846154
# dtype: float64
#
# Cluster 3
# Age       26.733333
# Income    54.311111
# Score     40.911111
# dtype: float64
#
# Cluster 4
# Age       44.387097
# Income    89.774194
# Score     18.483871
# dtype: float64

# %% [markdown]
# ***Visualisation***

# %%
for i in range(5):
    plt.scatter(
        df[df["Cluster"] == i]["Income"],
        df[df["Cluster"] == i]["Score"],
        label=f"Cluster {i}"
    )

plt.xlabel("Income")
plt.ylabel("Spending Score")
plt.title("Customer Segmentation")
plt.legend()
plt.show()

# %% [markdown]
# Feature Importance

# %%
import pandas as pd

feature_importance = pd.Series(
    model.feature_importances_,
    index=X_sup.columns
).sort_values(ascending=False)

feature_importance.plot(kind="bar")
plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

#  Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

#  Créer le modèle kmeans
kmeans = KMeans(n_clusters=3, random_state=42)

#  ENTRAÎNEMENT
kmeans.fit(X_scaled)

#  Calcul des distances
distances = kmeans.transform(X_scaled)

#  Distance au centre le plus proche
df["Distance_to_center"] = np.min(distances, axis=1)

print(df.head())
# Out:
#    CustomerID  Genre  Age  Income  Score  Cluster  Distance_to_center
# 0           1      0   19      15     39        2            1.349318
# 1           2      0   21      15     81        2            1.468602
# 2           3      1   20      16      6        3            2.250415
# 3           4      1   23      16     77        2            1.319069
# 4           5      1   31      17     40        2            1.262068

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(model, X_sup, y_sup, cv=5)
print(scores.mean())
# Out:
# 0.9199999999999999

# %% [markdown]
# ***Supervised Learning***

# %%
X_sup = df[["Age", "Income", "Score"]]
y_sup = df["Cluster"]

X_train, X_test, y_train, y_test = train_test_split(
    X_sup, y_sup, test_size=0.2, random_state=42
)

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         5
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00        12
#            4       1.00      1.00      1.00        10
#
#     accuracy                           1.00        40
#    macro avg       1.00      1.00      1.00        40
# weighted avg       1.00      1.00      1.00        40

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=df["Cluster"])
plt.show()

# %%
kmeans = KMeans(
    n_clusters=5,
    init='k-means++',   # meilleur initialisation
    n_init=10,
    max_iter=300,
    random_state=42)

# %% [markdown]
# Distance au centre

# %%
import pandas as pd

feature_importance = pd.Series(
    model.feature_importances_,
    index=X_sup.columns
).sort_values(ascending=False)

print(feature_importance)

feature_importance.plot(kind="bar")
plt.title("Feature Importance")
plt.show()
# Out:
# Age       0.361540
# Income    0.332595
# Score     0.305865
# dtype: float64

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(model, X_sup, y_sup, cv=5)

print("Cross-validation scores:", scores)
print("Mean score:", scores.mean())
# Out:
# Cross-validation scores: [0.825 0.975 1.    1.    0.775]
# Mean score: 0.915

# %%
from sklearn.ensemble import IsolationForest

iso = IsolationForest(contamination=0.05)
df["Anomaly"] = iso.fit_predict(X_scaled)

print(df["Anomaly"].value_counts())
# Out:
# Anomaly
#  1    190
# -1     10
# Name: count, dtype: int64

# %%
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("model", KMeans(n_clusters=5))
])

pipeline.fit(X)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('model', KMeans(n_clusters=5))])

# %% [markdown]
# Détection des outliers

# %%
threshold = df["Distance_to_center"].quantile(0.95)

outliers = df[df["Distance_to_center"] > threshold]

print("Outliers:\n", outliers)
# Out:
# Outliers:
#       CustomerID  Genre  Age  Income  Score  Cluster  Distance_to_center  \
# 2             3      1   20      16      6        3            2.250415
# 6             7      1   35      18      6        3            2.230915
# 8             9      0   64      19      3        0            2.201090
# 134         135      0   20      73      5        3            2.328611
# 138         139      0   19      74     10        3            2.197735
# 162         163      0   19      81      5        3            2.503363
# 192         193      0   33     113      8        4            2.559078
# 194         195      1   47     120     16        4            2.382506
# 196         197      1   45     126     28        4            2.539690
# 198         199      0   32     137     18        4            3.063532
#
#      Anomaly
# 2         -1
# 6          1
# 8         -1
# 134        1
# 138        1
# 162        1
# 192       -1
# 194       -1
# 196       -1
# 198       -1

# %% [markdown]
# Ajouter une vraie valeur business

# %%
def label_cluster(cluster):
    if cluster == 0:
        return "Low Value"
    elif cluster == 1:
        return "High Spenders"
    elif cluster == 2:
        return "Rich Customers"
    elif cluster == 3:
        return "Average"
    else:
        return "Premium"

df["Segment"] = df["Cluster"].apply(label_cluster)

print(df[["Cluster", "Segment"]].head())
# Out:
#    Cluster         Segment
# 0        2  Rich Customers
# 1        2  Rich Customers
# 2        3         Average
# 3        2  Rich Customers
# 4        2  Rich Customers

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=0.8, min_samples=5)
df["DBSCAN_Cluster"] = dbscan.fit_predict(X_scaled)

print(df["DBSCAN_Cluster"].value_counts())
# Out:
# DBSCAN_Cluster
#  0    194
# -1      6
# Name: count, dtype: int64

# %%
sns.scatterplot(
    x="Income",
    y="Score",
    hue="Segment",
    data=df,
    palette="Set2"
)
plt.title("Customer Segmentation (Business View)")
plt.show()

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=df["Cluster"])
plt.title("Clusters Visualization (PCA)")
plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.show()

# %%
score = silhouette_score(X_scaled, df["Cluster"])
print("Silhouette Score:", score)
# Out:
# Silhouette Score: 0.40846873777345605

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         5
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00        12
#            4       1.00      1.00      1.00        10
#
#     accuracy                           1.00        40
#    macro avg       1.00      1.00      1.00        40
# weighted avg       1.00      1.00      1.00        40

# %%
plt.scatter(df["Income"], df["Score"], c=df["Cluster"])
plt.xlabel("Income")
plt.ylabel("Spending Score")
plt.title("Customer Segments")
plt.show()
